# %% [markdown]
# The order of the cases is mysterious.
#  Variables
# There are 14 attributes in each case of the dataset. They are:
# 1.	CRIM - per capita crime rate by town
# 2.	ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# 3.	INDUS - proportion of non-retail business acres per town.
# 4.	CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# 5.	NOX - nitric oxides concentration (parts per 10 million)
# 6.	RM - average number of rooms per dwelling
# 7.	AGE - proportion of owner-occupied units built prior to 1940
# 8.	DIS - weighted distances to five Boston employment centres
# 9.	RAD - index of accessibility to radial highways
# 10.	TAX - full-value property-tax rate per $10,000
# 11.	PTRATIO - pupil-teacher ratio by town
# 12.	B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13.	LSTAT - % lower status of the population
# 14.	MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# Step 1:reading the data

# %%
import os
print(os.getcwd())
os.chdir('C:/Users/deeks/Desktop/my documents/data science class/assignments/assignment 3')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter

data = pd.read_csv("Train.csv")
# Out:
# C:\Users\deeks\Desktop\my documents\data science class\assignments\assignment 3

# %% [markdown]
# Step 2:variable  identification

# %%
data.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
data.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# this will give us the details of values i.e. the data type,no.of entries and also it will give the details if there exists any null values
#
#
# hence for this data we dont  have any null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
# ID         333 non-null int64
# crim       333 non-null float64
# zn         333 non-null float64
# indus      333 non-null float64
# chas       333 non-null int64
# nox        333 non-null float64
# rm         333 non-null float64
# age        333 non-null float64
# dis        333 non-null float64
# rad        333 non-null int64
# tax        333 non-null int64
# ptratio    333 non-null float64
# black      333 non-null float64
# lstat      333 non-null float64
# medv       333 non-null float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %%
#plt.subplot(nrows-ncols-index)
#Lets use subplot to get multiple plot outputs at the same time
plt.subplot(221)
plt.hist(data.crim,rwidth=1,bins=150) #rwidth sets width of bars.If it's 1 then the bars will touch each other
plt.xlabel("per capita crime rate by town")
plt.ylabel("count")
plt.subplot(222)
plt.hist(data.zn,bins=50) #rwidth sets width of bars.If it's 1 then the bars will touch each other
plt.xlabel("residential land")
plt.ylabel("proportion")
plt.subplot(223)
plt.hist(data.indus,bins=50)
plt.xlabel("non-retail business acres per town")
plt.ylabel("proportion")
plt.subplot(224)
plt.hist(data.chas,bins=50)
plt.xlabel(" Charles River")
plt.ylabel("variable")
plt.tight_layout()          # this function makes sure the plots dont overlap.Comment this and execute to observe the difference
plt.show()

# %%
plt.subplot(221)
plt.hist(data.nox,bins=50)
plt.xlabel("nitric oxides")
plt.ylabel("concentration")
plt.subplot(222)
plt.hist(data.rm,bins=50)
plt.xlabel("average number of rooms")
plt.ylabel("per dwelling")
plt.subplot(223)
plt.hist(data.age,bins=50)
plt.xlabel("owner-occupied units built prior to 1940")
plt.ylabel("proportion")
plt.subplot(224)
plt.hist(data.dis,bins=50)
plt.xlabel("five Boston employment centres")
plt.ylabel("distance")
plt.tight_layout()          # this function makes sure the plots dont overlap.Comment this and execute to observe the difference
plt.show()

# %%
plt.subplot(221)
plt.hist(data.rad,bins=50)
plt.xlabel("accessibility to radial highways")
plt.ylabel("index")
plt.subplot(222)
plt.hist(data.tax,bins=50)
plt.xlabel("full-value property-tax")
plt.ylabel("rate per $10,000")
plt.subplot(223)
plt.hist(data.ptratio,bins=50)
plt.xlabel("pupil-teacher")
plt.ylabel("ratio by town")
plt.subplot(224)
plt.hist(data.black,bins=5)
plt.xlabel("blacks by town")
plt.ylabel("proportion")
plt.tight_layout()          # this function makes sure the plots dont overlap.Comment this and execute to observe the difference
plt.show()

# %%
plt.subplot(221)
plt.hist(data.lstat,bins=100)
plt.xlabel("lower status of the population")
plt.ylabel("percentage")
plt.subplot(222)
plt.hist(data.medv,bins=100)
plt.xlabel("owner-occupied homes")
plt.ylabel("median value")
plt.tight_layout()          # this function makes sure the plots dont overlap.Comment this and execute to observe the difference
plt.show()

# %% [markdown]
# Since the main goal of this project is to construct a working model which has the capability of predicting the price  of houses, we will need to separate the dataset into features and the target variable. The features will be 'RM', 'LSTAT','CM' and 'PTRATIO', give us quantitative information about each data point. The target variable, 'MEDV', will be the variable we seek to predict.

# %%
data.medv.describe()
# Out:
# count    333.000000
# mean      22.768769
# std        9.173468
# min        5.000000
# 25%       17.400000
# 50%       21.600000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %%
plt.hist(data.medv,bins=100,rwidth=2)
plt.xlabel("Median value of owner-occupied homes in $1000's ")
plt.ylabel("price")
plt.show()

# %%
data[["rm","lstat","ptratio","crim"]].describe()
# Out:
#                rm       lstat     ptratio        crim
# count  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   12.515435   18.448048    3.360341
# std      0.703952    7.067781    2.151821    7.352272
# min      3.561000    1.730000   12.600000    0.006320
# 25%      5.884000    7.180000   17.400000    0.078960
# 50%      6.202000   10.970000   19.000000    0.261690
# 75%      6.595000   16.420000   20.200000    3.678220
# max      8.725000   37.970000   21.200000   73.534100

# %% [markdown]
# the crime rate is zero for most of the  values

# %% [markdown]
# The target 'MDEV' (or is it 'MEDV' for "median value"?) will increase as 'RM' increases. More rooms equals more square feet of property, hence a larger property value.
# 'MDEV' would rise as 'LSTAT' decreases, and we can see this using an extreme case.
# 'PTRATIO' will be inversely related to 'MDEV'. More teachers generally means better schools, which bolsters house prices in a given area.

# %%
plt.scatter(x=data.rm,y=data.medv)
plt.xlabel("avg rooms per dwelling")
plt.ylabel("median value")
plt.show()

# %%
plt.scatter(x=data.lstat,y=data.medv)
plt.xlabel("% lower status of the population")
plt.ylabel("median value")
plt.show()

# %%
plt.scatter(x=data.ptratio,y=data.medv)
plt.xlabel("pupil-teacher ratio by town")
plt.ylabel("median value")
plt.show()

# %% [markdown]
# this scatter plot has many segments.

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()
from pandas import Series, DataFrame
# %matplotlib inline

# %%
train=data

# %%
ind= np.isnan(train["medv"])
train=train.loc[-ind,:]
mylist = list(train.select_dtypes(include=['object']).columns)
train.drop(mylist, axis=1, inplace = True)

# %%
X = train.drop('medv',1)
x_train, x_cv, y_train, y_cv = train_test_split(X,train.medv, test_size =0.3)
lreg.fit(x_train,y_train)
pred_cv = lreg.predict(x_cv)
mse = np.mean((pred_cv - y_cv)**2)
print(lreg.score(x_cv,y_cv))
print(mse)
# Out:
# 0.6538514520344965
# 23.22020224283675

# %%
sns.reset_orig()
predictors = x_train.columns

coef = Series(lreg.coef_,predictors).sort_values()

coef.plot(kind='bar', title='Modal Coefficients')
plt.show()

# %%
#Choosing the best features
import statsmodels.api as sm
X2 = sm.add_constant(x_train)
est = sm.OLS(y_train, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.738
# Model:                            OLS   Adj. R-squared:                  0.722
# Method:                 Least Squares   F-statistic:                     43.96
# Date:                Tue, 23 Oct 2018   Prob (F-statistic):           1.54e-55
# Time:                        21:24:10   Log-Likelihood:                -699.18
# No. Observations:                 233   AIC:                             1428.
# Df Residuals:                     218   BIC:                             1480.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         23.0671      8.208      2.810      0.005       6.890      39.244
# ...

# %%
from sklearn.feature_selection import f_regression
p_val=list(f_regression(x_train, y_train, center=True))[1]
print(p_val)
# Out:
# [1.94231098e-04 1.03626807e-10 5.89996413e-06 4.45551294e-13
#  7.46947663e-04 1.28906405e-08 5.56741442e-40 6.24213005e-06
#  8.27988119e-04 8.13111050e-08 4.34740368e-13 2.41342330e-15
#  3.86390970e-08 1.79250777e-39]

# %%
f_regression(x_train, y_train, center=True)
# Out:
# (array([ 14.34373696,  45.86974124,  21.50766087,  58.9985084 ,
#          11.67880528,  34.80185627, 262.81356701,  21.38949121,
#          11.47757544,  30.71342698,  59.05920079,  72.20187751,
#          32.35574891, 257.85827798]),
#  array([1.94231098e-04, 1.03626807e-10, 5.89996413e-06, 4.45551294e-13,
#         7.46947663e-04, 1.28906405e-08, 5.56741442e-40, 6.24213005e-06,
#         8.27988119e-04, 8.13111050e-08, 4.34740368e-13, 2.41342330e-15,
#         3.86390970e-08, 1.79250777e-39]))

# %%
import seaborn as sns
corr = x_train.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
